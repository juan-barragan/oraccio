# %%
import pandas as pd
from collections import defaultdict

class dispatcher():
    def __init__(self, file_path):
        df = pd.read_csv(file_path)
        df = df.dropna(subset=['Identificativo', 'Materia', 'Classi', 'N.Ore'])
        df['N.Ore'] = df['N.Ore'].astype(int)
        self.df = df

        self.assignments = defaultdict(int)
        for _, row in df.iterrows():
            teacher = row['Identificativo']
            class_name = row['Classi']
            subject = row['Materia']
            hours = row['N.Ore']
            key = (teacher, class_name, subject)
            self.assignments[key] += hours

    def get_resource(self):
        items = sorted(self.assignments.items(), key=lambda x: x[1])
        if len(items)>0:
            return items[0]
        return None
    
    def pop_resource(self, key):
        if key in self.assignments:
            if self.assignments[key]>0:
                self.assignments[key] -= 1
            if self.assignments[key]==0:
                del self.assignments[key]
                return True
        return False

# %%
file_path = './data/conseil_docente_cleaned.csv'
dispatcher_instance = dispatcher(file_path)

df = pd.read_csv(file_path)
df = df.dropna(subset=['Identificativo', 'Materia', 'Classi', 'N.Ore'])
df['N.Ore'] = df['N.Ore'].astype(int)

# %%
classes = defaultdict(list)

for name, group in df.groupby('Classi'):
    classes[name] = list(zip(group['Identificativo'], group['Materia'], group['N.Ore']))

# %%
classes
# Out:
# defaultdict(list,
#             {'1A': [('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('CAVADI A.', 'FISICA', 2),
#               ('CERNIGLIARO M.', 'EC.AZ.', 2),
#               ('COLLETTO L.', 'INF', 2),
#               ('FOLLONE M.', 'ING', 3),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('GAMBINO F.', 'FRA', 3),
#               ('MESSINA R.', 'ITA', 4),
#               ('MESSINA R.', 'STO', 2),
#               ('MURATORE D.', 'MAT', 4),
#               ('NICCHITTA D.', 'GEO', 3),
#               ('PEDONE P.', 'DIR.EC.', 2),
#               ('RISO R.', 'REL', 1)],
#              '1B': [('ANSELMO A.', 'ING', 3),
#               ('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('BUCCHERI C.', 'DIR.EC.', 2),
#               ('CAVADI A.', 'FISICA', 2),
#               ('COLLETTO L.', 'INF', 2),
#               ('DI CARLO E.', 'EC.AZ.', 2),
#               ('LUFT S.', 'TED', 3),
#               ('RACCUGLIA A', 'MAT', 4),
#               ('SCAMBIA P.', 'REL', 1),
#               ('SUCATO V.', 'GEO', 3),
#               ('TERMINE G.', 'STO', 2),
#               ('TERMINE G.', 'ITA', 4)],
#              '1C': [('ARMETTA R.', 'INF', 2),
#               ('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('CAVADI A.', 'FISICA', 2),
#               ('CIOFALO M.', 'TED', 3),
#               ('COTILLUZZO R.', 'MAT', 4),
#               ('FARSETTA M.', 'STO', 2),
#               ('FARSETTA M.', 'ITA', 4),
#               ('FOLLONE M.', 'ING', 3),
#               ('FRISINA M.C.', 'EC.AZ.', 2),
#               ('LUCIDO M.', 'GEO', 3),
#               ('PEDONE P.', 'DIR.LEG.TUR.', 2),
#               ('SORCI A.', 'REL', 1),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2)],
#              '1D': [('ARMETTA R.', 'INF', 2),
#               ('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('CAVADI A.', 'FISICA', 2),
#               ('DRAGO R.', 'EC.AZ.', 2),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('MONTEROSSO R.', 'MAT', 4),
#               ('PEDONE P.', 'DIR.EC.', 2),
#               ('POLIZZOTTO L.', 'GEO', 3),
#               ('SAMPINO I.', 'ING', 3),
#               ('SORCI A.', 'REL', 1),
#               ('SPAGNOLO  2.', 'SPA', 3),
#               ('TERMINE G.', 'ITA', 4),
#               ('TERMINE G.', 'STO', 2)],
#              '1E': [('ALLEGRA P.', 'ING', 3),
#               ('ARMETTA R.', 'INF', 2),
#               ('BONDI G.', 'DIR.EC.', 2),
#               ('CAVADI A.', 'FISICA', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('MACCATAIO S.', 'MAT', 4),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('NICCHITTA D.', 'GEO', 3),
#               ('PASSARO G.', 'FRA', 3),
#               ('PATERNO A.', 'EC.AZ.', 2),
#               ('RICCOBONO A.', 'ITA', 4),
#               ('RICCOBONO A.', 'STO', 2),
#               ('SORCI A.', 'REL', 1)],
#              '1F': [('ARMETTA R.', 'INF', 2),
#               ('BUCCHERI C.', 'DIR.EC.', 2),
#               ('CALLIVA R.', 'ITA', 4),
#               ('CALLIVA R.', 'STO', 2),
#               ('CAVADI A.', 'FISICA', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('DI CARLO E.', 'D.T.A.', 2),
#               ('GIAMMANCO N.', 'MAT', 4),
#               ('GUARCELLO M.', 'FRA', 3),
#               ('LAGUARDIA E.', 'GEO', 3),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('MOSCA M.', 'ING', 3),
#               ('SCAMBIA P.', 'REL', 1)],
#              '1G': [('ARMETTA R.', 'INF', 2),
#               ('CAVADI A.', 'FISICA', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('LI MULI L.', 'GEO', 3),
#               ('MANNO T.', 'EC.AZ.', 2),
#               ('MENDOLA F.', 'MAT', 4),
#               ('NICOSIA M.', 'ING', 3),
#               ('ORLANDO E.', 'SPA', 3),
#               ('RINCIARI R.', 'DIR.EC.', 2),
#               ('SCAMBIA P.', 'REL', 1),
#               ('SOLE A.', 'ITA', 4),
#               ('SOLE A.', 'STO', 2),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2)],
#              '1H': [('BONANNO A.', 'DIR.EC.', 2),
#               ('CAVADI A.', 'FISICA', 2),
#               ('COLLETTO L.', 'INF', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('FRANCO G.', 'MAT', 4),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('MILITELLO G.', 'ITA', 4),
#               ('MILITELLO G.', 'STO', 2),
#               ('MINGRINO C.', 'SPA', 3),
#               ('MOSCA M.', 'ING', 3),
#               ('RICCIARDI G.', 'EC.AZ.', 2),
#               ('SCAMBIA P.', 'REL', 1),
#               ('SUCATO V.', 'GEO', 3)],
#              '1I': [('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('CAMMALLERI F.', 'FISICA', 2),
#               ("D'ANGELO M.", 'SCIENZE TERRA E BIOL', 2),
#               ('GRAFFAGNINO G.', 'EC.AZ.', 2),
#               ('IRACI S.', 'INF', 2),
#               ('LO PICCOLO D.', 'ING', 3),
#               ('LO PICCOLO D.+ROBERSON C.', 'ING', 1),
#               ('LO PICCOLO D.+ROBERSON C.', 'ING', 1),
#               ('LUCIDO M.', 'GEO', 3),
#               ('MESSINA R.', 'ITA', 4),
#               ('MESSINA R.', 'STO', 2),
#               ('MINAFO M.', 'MAT', 4),
#               ('RINCIARI R.', 'DIR.EC.', 2),
#               ('ROBERSON C.', 'ING', 1),
#               ('SCAGLIONE C.', 'SPA', 3),
#               ('SORCI A.', 'REL', 1)],
#              '1L': [('BONURA A.', 'MAT', 4),
#               ('CAVADI A.', 'FISICA', 2),
#               ('COLLETTO L.', 'INF', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('CUSIMANO M.', 'ITA', 4),
#               ('CUSIMANO M.', 'STO', 2),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('IANNOTTA D.', 'ING', 3),
#               ('IANNOTTA D.+ROBERSON C.', 'ING', 1),
#               ('IANNOTTA D.+ROBERSON C.', 'ING', 1),
#               ('NICCHITTA D.', 'GEO', 3),
#               ('PEDONE P.', 'DIR.EC.', 2),
#               ('RISO R.', 'REL', 1),
#               ('ROBERSON C.', 'ING', 1),
#               ('SAELI A.', 'EC.AZ.', 2),
#               ('SPINNATO N.', 'FRA', 3)],
#              '1M': [('ANSELMO A.', 'ING', 3),
#               ('BONURA A.', 'MAT', 4),
#               ('BUCCHERI C.', 'DIR.EC.', 2),
#               ('CAMMALLERI F.', 'FISICA', 2),
#               ("D'ANGELO M.", 'SCIENZE TERRA E BIOL', 2),
#               ('FARSETTA M.', 'ITA', 4),
#               ('FARSETTA M.', 'STO', 2),
#               ('INGA A.', 'SCIENZE MOT. E SPORT', 2),
#               ('IRACI S.', 'INF', 2),
#               ('LI MULI L.', 'GEO', 3),
#               ('MANNO T.', 'EC.AZ.', 2),
#               ('ORLANDO E.', 'SPA', 3),
#               ('SORCI A.', 'REL', 1)],
#              '2A': [('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('CERNIGLIARO M.', 'EC.AZ.', 2),
#               ('COLLETTO L.', 'INF', 2),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('LO PICCOLO D.', 'ING', 3),
#               ('MESSINA R.', 'STO', 2),
#               ('MESSINA R.', 'ITA', 4),
#               ('MURATORE D.', 'MAT', 4),
#               ('NICCHITTA D.', 'GEO', 3),
#               ('PASSARO G.', 'FRA', 3),
#               ('PEDONE P.', 'DIR.EC.', 2),
#               ('RISO R.', 'REL', 1),
#               ('VENEZIA M.', 'CHIMICA', 2)],
#              '2B': [('ANSELMO A.', 'ING', 3),
#               ('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('BUCCHERI C.', 'DIR.EC.', 2),
#               ('COLLETTO L.', 'INF', 2),
#               ('DI CARLO E.', 'GEO', 2),
#               ('LUFT S.', 'TED', 3),
#               ('RACCUGLIA A', 'MAT', 4),
#               ('SCAMBIA P.', 'REL', 1),
#               ('SUCATO V.', 'GEO', 3),
#               ('VENEZIA M.', 'CHIMICA', 2),
#               ('ZAGONE P.', 'ITA', 4),
#               ('ZAGONE P.', 'STO', 2)],
#              '2C': [('ARMETTA R.', 'INF', 2),
#               ('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('COTILLUZZO R.', 'MAT', 4),
#               ('FARSETTA M.', 'ITA', 4),
#               ('FARSETTA M.', 'STO', 2),
#               ('FOLLONE M.', 'ING', 3),
#               ('FRISINA M.C.', 'EC.AZ.', 2),
#               ('INGA A.', 'SCIENZE MOT. E SPORT', 2),
#               ('LO CICERO I', 'TED', 3),
#               ('LUCIDO M.', 'GEO', 3),
#               ('PEDONE P.', 'DIR.EC.', 2),
#               ('SORCI A.', 'REL', 1),
#               ('VENEZIA M.', 'CHIMICA', 2)],
#              '2D': [('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('BUCCHERI C.', 'DIR.EC.', 2),
#               ('COLLETTO L.', 'INF', 2),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('MONTEROSSO R.', 'MAT', 4),
#               ('PATERNO A.', 'EC.AZ.', 2),
#               ('POLIZZOTTO L.', 'GEO', 3),
#               ('SAMPINO I.', 'ING', 3),
#               ('SORCI A.', 'REL', 1),
#               ('SPAGNOLO  2.', 'SPA', 3),
#               ('TERMINE G.', 'STO', 2),
#               ('TERMINE G.', 'ITA', 4),
#               ('VENEZIA M.', 'CHIMICA', 2)],
#              '2E': [('ARMETTA R.', 'INF', 2),
#               ('BONDI G.', 'DIR.EC.', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('GAMBINO F.', 'FRA', 3),
#               ('GIUNTA A.', 'ING', 3),
#               ('MACCATAIO S.', 'MAT', 4),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('NICCHITTA D.', 'GEO', 3),
#               ('PATERNO A.', 'EC.AZ.', 2),
#               ('RICCOBONO A.', 'ITA', 4),
#               ('RICCOBONO A.', 'STO', 2),
#               ('SORCI A.', 'REL', 1),
#               ('VENEZIA M.', 'CHIMICA', 2)],
#              '2F': [('ARMETTA R.', 'INF', 2),
#               ('BUCCHERI C.', 'DIR.EC.', 2),
#               ('CAMMALLERI F.', 'MAT', 4),
#               ('CERNIGLIARO M.', 'EC.AZ.', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('GUARCELLO M.', 'FRA', 3),
#               ('LAGUARDIA E.', 'GEO', 3),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('MOSCA M.', 'ING', 3),
#               ('SCAMBIA P.', 'REL', 1),
#               ('VENEZIA M.', 'CHIMICA', 2),
#               ('ZAGONE P.', 'STO', 2),
#               ('ZAGONE P.', 'ITA', 4)],
#              '2G': [('ARMETTA R.', 'INF', 2),
#               ('BUA M.', 'SCIENZE TERRA E BIOL', 2),
#               ('CUSIMANO M.', 'STO', 2),
#               ('CUSIMANO M.', 'ITA', 4),
#               ('LI MULI L.', 'GEO', 3),
#               ('MANNO T.', 'EC.AZ.', 2),
#               ('MENDOLA F.', 'MAT', 4),
#               ('NICOSIA M.', 'ING', 3),
#               ('ORLANDO E.', 'SPA', 3),
#               ('RINCIARI R.', 'DIR.EC.', 2),
#               ('SCAMBIA P.', 'REL', 1),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2),
#               ('VENEZIA M.', 'CHIMICA', 2)],
#              '2H': [('BONANNO A.', 'DIR.EC.', 2),
#               ('COLLETTO L.', 'INF', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('FRANCO G.', 'MAT', 4),
#               ('FRISINA M.C.', 'EC.AZ.', 2),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('MILITELLO G.', 'ITA', 4),
#               ('MILITELLO G.', 'STO', 2),
#               ('MOSCA M.', 'ING', 3),
#               ('RISO R.', 'REL', 1),
#               ('STORNAIUOLO L.', 'SPA', 3),
#               ('SUCATO V.', 'GEO', 3),
#               ('VENEZIA M.', 'CHIMICA', 2)],
#              '2I': [('BARBO F.', 'STO', 2),
#               ('BARBO F.', 'ITA', 4),
#               ('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ("D'ANGELO M.", 'SCIENZE TERRA E BIOL', 2),
#               ('IRACI S.', 'INF', 2),
#               ('LO PICCOLO D.', 'ING', 2),
#               ('LO PICCOLO D.+ROBERSON C.', 'ING', 1),
#               ('LO PICCOLO D.+ROBERSON C.', 'ING', 1),
#               ('LUCIDO M.', 'GEO', 3),
#               ('MINAFO M.', 'MAT', 4),
#               ('RINCIARI R.', 'DIR.EC.', 3),
#               ('ROBERSON C.', 'ING', 1),
#               ('SAELI A.', 'EC.AZ.', 2),
#               ('SCAGLIONE C.', 'SPA', 3),
#               ('SORCI A.', 'REL', 1),
#               ('VENEZIA M.', 'CHIMICA', 2)],
#              '2L': [('BONURA A.', 'MAT', 4),
#               ('COLLETTO L.', 'INF', 2),
#               ('COLOMBINO E.', 'SCIENZE TERRA E BIOL', 2),
#               ('CUSIMANO M.', 'ITA', 4),
#               ('CUSIMANO M.', 'STO', 2),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('IANNOTTA D.', 'ING', 2),
#               ('IANNOTTA D.+ROBERSON C.', 'ING', 1),
#               ('IANNOTTA D.+ROBERSON C.', 'ING', 1),
#               ('NICCHITTA D.', 'GEO', 3),
#               ('PEDONE P.', 'DIR.EC.', 3),
#               ('RISO R.', 'REL', 1),
#               ('ROBERSON C.', 'ING', 1),
#               ('SAELI A.', 'EC.AZ.', 2),
#               ('SPINNATO N.', 'FRA', 3),
#               ('VENEZIA M.', 'CHIMICA', 2)],
#              '3A': [('CELESTRI R.', 'DIR.LEG.TUR.', 3),
#               ('CERNIGLIARO M.', 'D.T.A.', 4),
#               ('FARINA T.', 'ARTE', 2),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('IMMESI M.', 'SPA', 3),
#               ('LO PICCOLO D.', 'ING', 3),
#               ('MONTELEONE O.', 'ITA', 4),
#               ('MONTELEONE O.', 'STO', 2),
#               ('MURATORE D.', 'MAT', 3),
#               ('PASSARO G.', 'FRA', 3),
#               ('RISO R.', 'REL', 1),
#               ('SUCATO V.', 'GEO.TUR.', 2)],
#              '3B': [('ANSELMO A.', 'ING', 3),
#               ('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('DALIA S.', 'GEO.TUR.', 2),
#               ('DI CARLO E.', 'D.T.A.', 4),
#               ('FARINA T.', 'ARTE', 2),
#               ('GAETANI C.', 'STO', 2),
#               ('GAETANI C.', 'ITA', 4),
#               ('LUFT S.', 'TED', 3),
#               ('MANNINO P.', 'DIR.LEG.TUR.', 3),
#               ('PALUMBO D.', 'FRA', 3),
#               ('RACCUGLIA A', 'MAT', 3),
#               ('SCAMBIA P.', 'REL', 1)],
#              '3C': [('CIOFALO M.', 'TED', 3),
#               ('COTILLUZZO R.', 'MAT', 3),
#               ('FOLLONE M.', 'ING', 3),
#               ('FRISINA M.C.', 'D.T.A.', 4),
#               ('GAGLIARDO E.', 'ITA', 4),
#               ('GAGLIARDO E.', 'STO', 2),
#               ('LUCIDO M.', 'GEO.TUR.', 2),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('SORCI A.', 'REL', 1),
#               ('STORNAIUOLO L.', 'SPA', 3),
#               ('TUMMINELLO A.', 'DIR.LEG.TUR.', 3),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2)],
#              '3D': [('CINA F.', 'ITA', 4),
#               ('CINA F.', 'STO', 2),
#               ('DRAGO R.', 'D.T.A.', 4),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('GUARCELLO M.', 'FRA', 3),
#               ('MONTEROSSO R.', 'MAT', 3),
#               ('POLIZZOTTO L.', 'GEO', 2),
#               ('SAMPINO I.', 'ING', 3),
#               ('SANSONE T.', 'ARTE', 2),
#               ('SORCI A.', 'REL', 1),
#               ('SPAGNOLO  2.', 'SPA', 3),
#               ('TUMMINELLO A.', 'DIR.LEG.TUR.', 3)],
#              '3E': [('BONDI G.', 'DIR.LEG.TUR.', 3),
#               ('CIOFALO M.', 'TED', 3),
#               ('DALIA S.', 'GEO', 2),
#               ('DI PIAZZA M.', 'ITA', 4),
#               ('DI PIAZZA M.', 'STO', 2),
#               ('GAMBINO F.', 'FRA', 4),
#               ('GIUNTA A.', 'ING', 3),
#               ('MACCATAIO S.', 'MAT', 3),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('PATERNO A.', 'D.T.A.', 4),
#               ('SORCI A.', 'REL', 1)],
#              '3F': [('GRAFFAGNINO G.', 'D.T.A.', 4),
#               ('GUARCELLO M.', 'FRA', 3),
#               ('IMMESI M.', 'SPA', 3),
#               ('LAGUARDIA E.', 'GEO.TUR.', 2),
#               ('MANNINO P.', 'DIR.LEG.TUR.', 3),
#               ('MINAFO M.', 'MAT', 3),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('MOSCA M.', 'ING', 3),
#               ('SANSONE T.', 'ARTE', 2),
#               ('SCAMBIA P.', 'REL', 1),
#               ('ZAGONE P.', 'ITA', 4),
#               ('ZAGONE P.', 'STO', 2)],
#              '3G': [("D'ELIA M.", 'STO', 2),
#               ("D'ELIA M.", 'ITA', 4),
#               ('MANNO T.', 'D.T.A.', 4),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('MENDOLA F.', 'MAT', 3),
#               ('NICOSIA M.', 'ING', 3),
#               ('ORLANDO E.', 'SPA', 3),
#               ('PALUMBO D.', 'FRA', 3),
#               ('POLIZZOTTO L.', 'GEO.TUR.', 2),
#               ('RINCIARI R.', 'DIR.LEG.TUR.', 3),
#               ('SCAMBIA P.', 'REL', 1),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2)],
#              '3H': [('ALLEGRA P.', 'ING', 3),
#               ('BONANNO A.', 'DIR.LEG.TUR.', 3),
#               ('DALIA S.', 'GEO', 2),
#               ('FRANCO G.', 'MAT', 3),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('LO CICERO I', 'TED', 3),
#               ('MANNO T.', 'D.T.A.', 4),
#               ('RISO R.', 'REL', 1),
#               ('SANSONE T.', 'ARTE', 2),
#               ('STORNAIUOLO L.', 'SPA', 3),
#               ('TANTILLO A.', 'ITA', 4),
#               ('TANTILLO A.', 'STO', 2)],
#              '3L': [('BONURA A.', 'MAT', 3),
#               ('CAMMARATA C.', 'ARTE', 2),
#               ('DI PIAZZA M.', 'ITA', 4),
#               ('DI PIAZZA M.', 'STO', 2),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('IANNOTTA D.', 'ING', 3),
#               ('LAGUARDIA E.', 'GEO.TUR.', 2),
#               ('LO CICERO I', 'TED', 3),
#               ('PEDONE P.', 'DIR.LEG.TUR.', 3),
#               ('RISO R.', 'REL', 1),
#               ('ROBERSON C.', 'ING', 3),
#               ('SAELI A.', 'D.T.A.', 4),
#               ('SPINNATO N.', 'FRA', 3),
#               ('STORNAIUOLO L.', 'SPA', 3)],
#              '4A': [('CELESTRI R.', 'DIR.LEG.TUR.', 3),
#               ('CERNIGLIARO M.', 'D.T.A.', 4),
#               ('FARINA T.', 'ARTE', 2),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('IMMESI M.', 'SPA', 3),
#               ('LO PICCOLO D.', 'ING', 3),
#               ('MONTELEONE O.', 'ITA', 4),
#               ('MONTELEONE O.', 'STO', 2),
#               ('MURATORE D.', 'MAT', 3),
#               ('PASSARO G.', 'FRA', 3),
#               ('RISO R.', 'REL', 1),
#               ('SUCATO V.', 'GEO.TUR.', 2)],
#              '4B': [('ANSELMO A.', 'ING', 3),
#               ('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('DALIA S.', 'GEO.TUR.', 2),
#               ('DI CARLO E.', 'D.T.A.', 4),
#               ('FARINA T.', 'ARTE', 2),
#               ('GAETANI C.', 'STO', 2),
#               ('GAETANI C.', 'ITA', 4),
#               ('LUFT S.', 'TED', 3),
#               ('MANNINO P.', 'DIR.LEG.TUR.', 3),
#               ('PALUMBO D.', 'FRA', 3),
#               ('RACCUGLIA A', 'MAT', 3),
#               ('SCAMBIA P.', 'REL', 1)],
#              '4C': [('COTILLUZZO R.', 'MAT', 3),
#               ('FOLLONE M.', 'ING', 3),
#               ('FRISINA M.C.', 'D.T.A.', 4),
#               ('GAGLIARDO E.', 'ITA', 4),
#               ('GAGLIARDO E.', 'STO', 2),
#               ('LUCIDO M.', 'GEO.TUR.', 2),
#               ('LUFT S.', 'TED', 3),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('SORCI A.', 'REL', 1),
#               ('STORNAIUOLO L.', 'SPA', 3),
#               ('TUMMINELLO A.', 'DIR.LEG.TUR.', 3),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2)],
#              '4D': [('CINA F.', 'ITA', 4),
#               ('CINA F.', 'STO', 2),
#               ('DRAGO R.', 'D.T.A.', 4),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('MONTEROSSO R.', 'MAT', 3),
#               ('PASSARO G.', 'FRA', 3),
#               ('POLIZZOTTO L.', 'GEO', 2),
#               ('RAPPA L.', 'SPA', 3),
#               ('SAMPINO I.', 'ING', 3),
#               ('SANSONE T.', 'ARTE', 2),
#               ('SORCI A.', 'REL', 1),
#               ('TUMMINELLO A.', 'DIR.LEG.TUR.', 3)],
#              '4E': [('BONDI G.', 'DIR.LEG.TUR.', 3),
#               ('CIOFALO M.', 'TED', 3),
#               ('DALIA S.', 'GEO.TUR.', 2),
#               ('DI PIAZZA M.', 'ITA', 4),
#               ('DI PIAZZA M.', 'STO', 2),
#               ('GAMBINO F.', 'FRA', 4),
#               ('GIUNTA A.', 'ING', 3),
#               ('MACCATAIO S.', 'MAT', 3),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('PATERNO A.', 'D.T.A.', 4),
#               ('SORCI A.', 'REL', 1)],
#              '4F': [('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('CALLIVA R.', 'ITA', 4),
#               ('CALLIVA R.', 'STO', 2),
#               ('GRAFFAGNINO G.', 'D.T.A.', 4),
#               ('GUARCELLO M.', 'FRA', 3),
#               ('IMMESI M.', 'SPA', 3),
#               ('LAGUARDIA E.', 'GEO.TUR.', 2),
#               ('MANNINO P.', 'DIR.LEG.TUR.', 3),
#               ('MOSCA M.', 'ING', 3),
#               ('RANDAZZO R.', 'MAT', 3),
#               ('SANSONE T.', 'ARTE', 2),
#               ('SCAMBIA P.', 'REL', 1)],
#              '4G': [("D'ELIA M.", 'STO', 2),
#               ("D'ELIA M.", 'ITA', 4),
#               ('MANNO T.', 'D.T.A.', 4),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('MENDOLA F.', 'MAT', 3),
#               ('NICOSIA M.', 'ING', 3),
#               ('ORLANDO E.', 'SPA', 3),
#               ('PALUMBO D.', 'FRA', 3),
#               ('POLIZZOTTO L.', 'GEO.TUR.', 2),
#               ('RINCIARI R.', 'DIR.LEG.TUR.', 3),
#               ('SCAMBIA P.', 'REL', 1),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2)],
#              '4H': [('BUCCHERI C.', 'DIR.LEG.TUR.', 3),
#               ('DALIA S.', 'GEO', 2),
#               ('FRANCO G.', 'MAT', 3),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('IANNOTTA D.', 'ING', 3),
#               ('LO CICERO I', 'TED', 3),
#               ('RICCIARDI G.', 'D.T.A.', 4),
#               ('RISO R.', 'REL', 1),
#               ('SANSONE T.', 'ARTE', 2),
#               ('SCAGLIONE C.', 'SPA', 3),
#               ('TANTILLO A.', 'ITA', 4),
#               ('TANTILLO A.', 'STO', 2)],
#              '4I': [('BARBO F.', 'STO', 2),
#               ('BARBO F.', 'ITA', 4),
#               ('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('BONAFFINI S.', 'DIR.LEG.TUR.', 3),
#               ('FARINA T.', 'ARTE', 2),
#               ('GRAFFAGNINO G.', 'D.T.A.', 4),
#               ('LAGUARDIA E.', 'GEO.TUR.', 2),
#               ('MINAFO M.', 'MAT', 3),
#               ('NICOSIA M.', 'ING', 3),
#               ('SCAGLIONE C.', 'SPA', 3),
#               ('SCAMBIA P.', 'REL', 1),
#               ('SPINNATO N.', 'FRA', 3)],
#              '5A': [('BONAFFINI S.', 'DIR.LEG.TUR.', 3),
#               ('CERNIGLIARO M.', 'D.T.A.', 4),
#               ('FARINA T.', 'ARTE', 2),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('GAMBINO F.', 'FRA', 3),
#               ('IMMESI M.', 'SPA', 3),
#               ('LO PICCOLO D.', 'ING', 3),
#               ('MONTELEONE O.', 'STO', 2),
#               ('MONTELEONE O.', 'ITA', 4),
#               ('MURATORE D.', 'MAT', 3),
#               ('RISO R.', 'REL', 1),
#               ('SUCATO V.', 'GEO.TUR.', 2)],
#              '5B': [('ANSELMO A.', 'ING', 3),
#               ('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('DALIA S.', 'GEO.TUR.', 2),
#               ('DI CARLO E.', 'D.T.A.', 4),
#               ('FARINA T.', 'ARTE', 2),
#               ('GAETANI C.', 'STO', 2),
#               ('GAETANI C.', 'ITA', 4),
#               ('LUFT S.', 'TED', 3),
#               ('MANNINO P.', 'DIR.LEG.TUR.', 3),
#               ('PALUMBO D.', 'FRA', 3),
#               ('RACCUGLIA A', 'MAT', 3),
#               ('SCAMBIA P.', 'REL', 1)],
#              '5C': [('CIOFALO M.', 'TED', 3),
#               ('COTILLUZZO R.', 'MAT', 3),
#               ('FOLLONE M.', 'ING', 3),
#               ('FRISINA M.C.', 'D.T.A.', 4),
#               ('GAGLIARDO E.', 'ITA', 4),
#               ('GAGLIARDO E.', 'STO', 2),
#               ('LUCIDO M.', 'GEO.TUR.', 2),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('RAPPA L.', 'SPA', 3),
#               ('SORCI A.', 'REL', 1),
#               ('TUMMINELLO A.', 'DIR.LEG.TUR.', 3),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2)],
#              '5D': [('CINA F.', 'ITA', 4),
#               ('CINA F.', 'STO', 2),
#               ('DRAGO R.', 'D.T.A.', 4),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('MONTEROSSO R.', 'MAT', 3),
#               ('POLIZZOTTO L.', 'GEO', 2),
#               ('RAPPA L.', 'SPA', 3),
#               ('SAMPINO I.', 'ING', 3),
#               ('SANSONE T.', 'ARTE', 2),
#               ('SORCI A.', 'REL', 1),
#               ('SPINNATO N.', 'FRA', 3),
#               ('TUMMINELLO A.', 'DIR.LEG.TUR.', 3)],
#              '5E': [('BONDI G.', 'DIR.LEG.TUR.', 3),
#               ('CIOFALO M.', 'TED', 3),
#               ('DALIA S.', 'GEO.TUR.', 2),
#               ('GIUNTA A.', 'ING', 3),
#               ('MACCATAIO S.', 'MAT', 3),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('PASSARO G.', 'FRA', 4),
#               ('PATERNO A.', 'D.T.A.', 4),
#               ('RICCOBONO A.', 'STO', 2),
#               ('RICCOBONO A.', 'ITA', 4),
#               ('SORCI A.', 'REL', 1)],
#              '5F': [('CALLIVA R.', 'STO', 2),
#               ('CALLIVA R.', 'ITA', 4),
#               ('CAMMALLERI F.', 'MAT', 3),
#               ('DRAGO R.', 'D.T.A.', 4),
#               ('GUARCELLO M.', 'FRA', 3),
#               ('IMMESI M.', 'SPA', 3),
#               ('LAGUARDIA E.', 'GEO.TUR.', 2),
#               ('MANNINO P.', 'DIR.LEG.TUR.', 3),
#               ('MONTALBANO B.', 'SCIENZE MOT. E SPORT', 2),
#               ('SAMPINO I.', 'ING', 3),
#               ('SANSONE T.', 'ARTE', 2),
#               ('SCAMBIA P.', 'REL', 1)],
#              '5G': [("D'ELIA M.", 'STO', 2),
#               ("D'ELIA M.", 'ITA', 4),
#               ('LI MULI L.', 'GEO.TUR.', 2),
#               ('MANNO T.', 'D.T.A.', 4),
#               ('MARTORANA R.', 'ARTE', 2),
#               ('MENDOLA F.', 'MAT', 3),
#               ('NICOSIA M.', 'ING', 3),
#               ('ORLANDO E.', 'SPA', 3),
#               ('PALUMBO D.', 'FRA', 3),
#               ('RINCIARI R.', 'DIR.LEG.TUR.', 3),
#               ('SCAMBIA P.', 'REL', 1),
#               ('VALGUARNERA S.', 'SCIENZE MOT. E SPORT', 2)],
#              '5H': [('DALIA S.', 'GEO', 2),
#               ('FRANCO G.', 'MAT', 3),
#               ('GALLO A.', 'SCIENZE MOT. E SPORT', 2),
#               ('IANNOTTA D.', 'ING', 3),
#               ('LO CICERO I', 'TED', 3),
#               ('PEDONE P.', 'DIR.LEG.TUR.', 3),
#               ('RICCIARDI G.', 'D.T.A.', 4),
#               ('RISO R.', 'REL', 1),
#               ('SANSONE T.', 'ARTE', 2),
#               ('SCAGLIONE C.', 'SPA', 3),
#               ('TANTILLO A.', 'ITA', 4),
#               ('TANTILLO A.', 'STO', 2)],
#              '5I': [('ALLEGRA P.', 'ING', 3),
#               ('BARBO F.', 'STO', 2),
#               ('BARBO F.', 'ITA', 4),
#               ('BASILE D.', 'SCIENZE MOT. E SPORT', 2),
#               ('BUCCHERI C.', 'DIR.LEG.TUR.', 3),
#               ('FARINA T.', 'ARTE', 2),
#               ('GRAFFAGNINO G.', 'D.T.A.', 4),
#               ('LAGUARDIA E.', 'GEO.TUR.', 2),
#               ('MINAFO M.', 'MAT', 3),
#               ('SCAGLIONE C.', 'SPA', 3),
#               ('SCAMBIA P.', 'REL', 1),
#               ('SPINNATO N.', 'FRA', 3)],
#              '5L': [('BONANNO A.', 'DIR.LEG.TUR.', 3),
#               ('BONURA A.', 'MAT', 3),
#               ('CAMMARATA C.', 'ARTE', 2),
#               ('GAMBINO F.', 'FRA', 3),
#               ('GIAMBALVO M.', 'SCIENZE MOT. E SPORT', 2),
#               ('IANNOTTA D.', 'ING', 3),
#               ('MILITELLO G.', 'ITA', 4),
#               ('MILITELLO G.', 'STO', 2),
#               ('POLIZZOTTO L.', 'GEO.TUR.', 2),
#               ('RISO R.', 'REL', 1),
#               ('SAELI A.', 'D.T.A.', 4),
#               ('STORNAIUOLO L.', 'SPA', 3)]})
